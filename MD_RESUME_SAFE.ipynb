# %% [markdown]
# <p style="text-align:left;"><b>
# ALEX CLIFTON</b><span style="float:right;">
# three four seven eight seven eight two four eight seven</span><br>
# alexander [dot] clifton [at] gmail [dot] com<span style="float:right;">
# alexclifton.com</span></p>
#
# <b>MY QUEST:</b> Create technology to understand, communicate, and act on reality and truth.
#
# <p style="text-align:left;"><b>
# ✪ SSLINGER</b> - sslinger.com<span style="float:right;">
# 💡 Beacon, New York</span><br>
# → Developer<span style="float:right;">
# Apr 2018 - Present</span></p>
#
# - Mobile app for art sales in niche market.
# - React Native, AWS AppSync, Apollo GraphQL, Aurora Serverless, Lambda
#
#
#
# <p style="text-align:left;"><b>
# ✪ CNNMoney / CNN MoneyStream</b> - cnnmoneystream.com / money.cnn.com<span style="float:right;">
# 🗽 New York City</span><br>
# → Senior Director Technology<span style="float:right;">
# Jun 2015 - Feb 2018</span></p>
#
# - Financial/Business/Markets News & Data - The Most Trusted Name in News
# - Built MoneyStream iOS & Android apps, fullstack, from the ground up
# - Hired high performing agile team (~8-14 devs): native mobile, mobile web/web, backend, api
# - Delivered MoneyStream on time with very aggressive timeline (~6 months)
# - Led Mobile Web Redesign - filled product & dev roles
#
# <p style="text-align:left;">
# </span></p>
#
# <p style="text-align:left;"><b>
# ✪ JAKT</b> - byjakt.com<span style="float:right;">
# 🗽 New York City</span><br>
# → Computer Scientist<span style="float:right;">
# Jul 2014 - Jun 2015</span></p>
#
# - Agency/consultancy: startup building apps for startups
# - Python Django Rest Framework API Development; Android App Dev
#
# <p style="text-align:left;"><b>
# ✪ NowThis News</b> - nowthisnews.com<span style="float:right;">
# 🗽 New York City</span><br>
# → Lead Developer / Filled in for departed CTO<span style="float:right;">
# Dec 2012 - Apr 2014 / Apr 2014 - Jul 2014</span></p>
#
# - Video News Network Distributed On Mobile Devices & Social Media
# - Video transcoding &amp; distribution system development (python, django, ffmpeg, +images)
# - Developed Android App for Play, Kindle, Nook, & Amazon Fire TV
# - Managed: iOS, Web redesigns - new feature inline player; Windows Phone 8 app dev
#
# <p style="text-align:left;"><b>
# ✪ USAA</b> - usaa.com<span style="float:right;">
# 🤠 San Antonio, Texas</span><br>
# → Software Developer &amp; Integrator II<span style="float:right;">
# Feb 2011 - Feb 2013</span></p>
#
# - Mobile development: Android, iOS, Mobile Web; Java WebSphere
#
# <b>Related Fields:</b> Land Surveyor; Film/Video; 3D Animation; Music;
#
# <p style="text-align:left;"><b>
# ✪ EDUCATION: Marist College</b> - marist.edu<span style="float:right;">
# 🎓 Poughkeepsie, New York</span></p>
#
# - BS Computer Science; game dev focus; Dean's List; Honor Society; Magna Cum Laude
#
# <p style="text-align:left;"><b>
# ✪ SKILLS / LANGUAGES / INTERESTS</b><span style="float:right;">
# 🧠 [just some]</span></p>
#
# + Python, React Native, Javascript, HTML, CSS, Java, Swift, Kotlin, React
# + Django Rest Framework, scikit-learn, OpenCV, NumPy, SciPy, Tensor Flow
# + GraphQL, serverless, matplotlib, Jupyter Notebook, FFMpeg, Apollo, D3
# + Natural Language Processing, Machine Learning, Computer Vision, Keras
# + Fintech, Geospatial, Amazon Web Services, AWS Lambda, PostgreSQL, Boto3
